# %% [markdown]
#  - https://huggingface.co/UNIST-Eunchan/FLAN-T5-NLP-Paper-to-Question-Generation?text=Generate+Question%2C+Answer+pair+correspond+to+the+following+research+paper.+%5BAbstract%5D+In+this+work%2C+we+explore+prompt+tuning%2C+a+simple+yet+effective+mechanism+for+learning+soft+prompts+to+condition+frozen+language+models+to+perform+specific+downstream+tasks.+Unlike+the+discrete+text+prompts+used+by+GPT-3%2C+soft+prompts+are+learned+through+backpropagation+and+can+be+tuned+to+incorporate+signal+from+any+number+of+labeled+examples.+Our+end-to-end+learned+approach+outperforms+GPT-3%27s+few-shot+learning+by+a+large+margin.+More+remarkably%2C+through+ablations+on+model+size+using+T5%2C+we+show+that+prompt+tuning+becomes+more+competitive+with+scale%3A+as+models+exceed+billions+of+parameters%2C+our+method+closes+the+gap+and+matches+the+strong+performance+of+model+tuning+%28where+all+model+weights+are+tuned%29.+This+finding+is+especially+relevant+in+that+large+models+are+costly+to+share+and+serve%2C+and+the+ability+to+reuse+one+frozen+model+for+multiple+downstream+tasks+can+ease+this+burden.+Our+method+can+be+seen+as+a+simplification+of+the+recently+proposed+prefix+tuning+of+Li+and+Liang+%282021%29%2C+and+we+provide+a+comparison+to+this+and+other+similar+approaches.+Finally%2C+we+show+that+conditioning+a+frozen+model+with+soft+prompts+confers+benefits+in+robustness+to+domain+transfer%2C+as+compared+to+full+model+tuning.+%5BIntroduction%5D+With+the+wide+success+of+pre-trained+large+language+models%2C+a+range+of+techniques+has+arisen+to+adapt+these+general-purpose+models+to+downstream+tasks.+ELMo+%28Peters+et+al.%2C+2018%29+proposed+freezing+the+pre-trained+model+and+learning+a+task-specific+weighting+of+its+per-layer+representations.+However%2C+since+GPT+%28Radford+et+al.%2C+2018%29+and+BERT+%28Devlin+et+al.%2C+2019%29%2C+the+dominant+adaptation+technique+has+been+model+tuning+%28or+fine-tuning%29%2C+where+all+model+parameters+are+tuned+during+adaptation%2C+as+proposed+by+Howard+and+Ruder+%282018%29.More+recently%2C+Brown+et+al.+%282020%29+showed+that+prompt+design+%28or+priming%29+is+surprisingly+effective+at+modulating+a+frozen+GPT-3+model%E2%80%99s+behavior+through+text+prompts.+Prompts+are+typically+composed+of+a+task+description+and%2For+several+canonical+examples.+This+return+to+freezing+pre-trained+models+is+appealing%2C+especially+as+model+size+continues+to+increase.+Rather+than+requiring+a+separate+copy+of+the+model+for+each+downstream+task%2C+a+single+generalist+model+can+simultaneously+serve+many+different+tasks.+Unfortunately%2C+prompt-based+adaptation+has+several+key+drawbacks.+Task+description+is+error-prone+and+requires+human+involvement%2C+and+the+effectiveness+of+a+prompt+is+limited+by+how+much+conditioning+text+can+fit+into+the+model%E2%80%99s+input.+As+a+result%2C+downstream+task+quality+still+lags+far+behind+that+of+tuned+models.+For+instance%2C+GPT-3+175B+fewshot+performance+on+SuperGLUE+is+17.5+points+below+fine-tuned+T5-XXL+%28Raffel+et+al.%2C+2020%29+%2871.8+vs.+89.3%29+despite+using+16+times+more+parameters.+Several+efforts+to+automate+prompt+design+have+been+recently+proposed.+Shin+et+al.+%282020%29+propose+a+search+algorithm+over+the+discrete+space+of+words%2C+guided+by+the+downstream+application+training+data.+While+this+technique+outperforms+manual+prompt+design%2C+there+is+still+a+gap+relative+to+model+tuning.+Li+and+Liang+%282021%29+propose+prefix+tuning+and+show+strong+results+on+generative+tasks.+This+method+freezes+the+model+parameters+and+backpropagates+the+error+during+tuning+to+prefix+activations+prepended+to+each+layer+in+the+encoder+stack%2C+including+the+input+layer.+Hambardzumyan+et+al.+%282021%29+simplify+this+recipe+by+restricting+the+trainable+parameters+to+the+input+and+output+subnetworks+of+a+masked+language+model%2C+and+show+reasonable+results+on+classifications+tasks.+In+this+paper%2C+we+propose+prompt+tuning+as+a+further+simplification+for+adapting+language+models.+We+freeze+the+entire+pre-trained+model+and+only+allow+an+additional+k+tunable+tokens+per+downstream+task+to+be+prepended+to+the+input+text.+This+soft+prompt+is+trained+end-to-end+and+can+condense+the+signal+from+a+full+labeled+dataset%2C+allowing+our+method+to+outperform+few-shot+prompts+and+close+the+quality+gap+with+model+tuning+%28Figure+1%29.+At+the+same+time%2C+since+a+single+pre-trained+model+is+recycled+for+all+downstream+tasks%2C+we+retain+the+efficient+serving+benefits+of+frozen+models+%28Figure+2%29.+While+we+developed+our+method+concurrently+with+Li+and+Liang+%282021%29+and+Hambardzumyan+et+al.+%282021%29%2C+we+are+the+first+to+show+that+prompt+tuning+alone+%28with+no+intermediate-layer+prefixes+or+task-specific+output+layers%29+is+sufficient+to+be+competitive+with+model+tuning.+Through+detailed+experiments+in+sections+2%E2%80%933%2C+we+demonstrate+that+language+model+capacity+is+a+key+ingredient+for+these+approaches+to+succeed.+As+Figure+1+shows%2C+prompt+tuning+becomes+more+competitive+with+scale.+We+compare+with+similar+approaches+in+Section+4.+Explicitly+separating+task-specific+parameters+from+the+generalist+parameters+needed+for+general+language-understanding+has+a+range+of+additional+benefits.+We+show+in+Section+5+that+by+capturing+the+task+definition+in+the+prompt+while+keeping+the+generalist+parameters+fixed%2C+we+are+able+to+achieve+better+resilience+to+domain+shifts.+In+Section+6%2C+we+show+that+prompt+ensembling%2C+learning+multiple+prompts+for+the+same+task%2C+can+boost+quality+and+is+more+efficient+than+classic+model+ensembling.+Finally%2C+in+Section+7%2C+we+investigate+the+interpretability+of+our+learned+soft+prompts.+In+sum%2C+our+key+contributions+are%3A+1.+Proposing+prompt+tuning+and+showing+its+competitiveness+with+model+tuning+in+the+regime+of+large+language+models.+2.+Ablating+many+design+choices%2C+and+showing+quality+and+robustness+improve+with+scale.+3.+Showing+prompt+tuning+outperforms+model+tuning+on+domain+shift+problems.+4.+Proposing+prompt+ensembling+and+showing+its+effectiveness.+%0A+Question%2C+Answer%3A

# %%
#load model
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("UNIST-Eunchan/FLAN-T5-NLP-Paper-to-Question-Generation")
model = AutoModelForSeq2SeqLM.from_pretrained("UNIST-Eunchan/FLAN-T5-NLP-Paper-to-Question-Generation")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/20.8k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/817 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.57G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %%
#prompting input
txt =  r"""
Generate Question, Answer pair correspond to the following paper.
[Abstract] + {text['abstract']} + [Introduction] + {text['introduction']}
Question, Answer:
""".replace("\n", "")

inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %% [markdown]
# # 0. Abstract 부분 -> 4/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[Abstract]
The credit rating system solves the problem of information imbalance between companies and investors
It has the effect of promoting the efficiency of the capital market. Therefore, in this study, the history of the credit rating industry is
Studies that examine and test the usefulness of credit rating information and factors that affect credit rating
By reviewing previous studies that have studied, we would like to review the usefulness and improvement factors of credit rating information.
As a result of the study, first, the reason for the development of the global credit rating industry was the development of the railroad industry in the United States
It started with the financing of railroad companies (creating corporate bonds). However, when the capital market develops
When a company wants to raise funds at a low cost of capital and investors want a safe place to invest
It can be said that the credit rating industry aims to resolve the imbalance of information between companies and investors
C. Second, the Korean bond market, like the early bond market in history, needs for credit ratings
However, as the issuance of unsecured bonds by credit expanded and made multiple valuations mandatory
As the demand for the credit rating system increased, it took the form of the three domestic credit rating companies in the 1980s. I
Furthermore, in order to introduce international credit rating techniques, business agreements with the three major international credit rating agencies are made
Beyond that, it has been incorporated into international credit rating agencies or is expanding its stake. Third, the credit rating industry is
It was developed to provide useful information for investors' decision-making. Therefore, capital market participants
They specialize in credit rating information published by credit rating agencies based on financial and non-financial information
It recognizes that new information from the appropriate credit rating agency is included and is reflected in investment decisions
It can be seen through the consideration of previous studies. Finally, fourth, it affects credit rating
As a result of reviewing previous studies on English and accounting issues, various factors affect credit ratings
You can see that it's crazy.
The role of credit rating is to present fair and professional opinions between bond issuers and investors
Finance by reducing risk to investors and providing issuers with the opportunity to raise stable capital
It is to improve the efficiency of the market. Therefore, the contribution of this study is the birth and development of the credit rating industry
In addition, historical considerations of the credit rating industry, such as the expanded credit rating area, and credit rating information in the capital market
While testing the usefulness of, consider previous studies that studied factors affecting credit ratings
By doing so, it can be said that it is very meaningful to examine the usefulness and improvement factors of credit rating information.
[Introduction]
In the early days of the Korean bond market, collateral-oriented bonds dominated, and companies secured
Capital costs, such as securing and evaluating collateral, have increased. However, firms are lower
The wants to be financed by capital costs and participants in capital markets are at low risk
I wanted a good investment destination. Lower the capital cost of bond issuers and reduce the risk of investors
In order to do this, we need to solve the problem of information imbalance between companies and investors
Solve it. One of the systems for this is the credit rating system. 1) Therefore, the credit rating system's
The correct settlement is the information between the bond issuing company and the investor structurally inherent in the capital market
While reducing investors' risk by mitigating the imbalance, wealth by collateral or guarantee
Capital of the enterprise by avoiding rising movable property prices or security valuation costs
cost) can be reduced (Jindong-min, 2013).
Korea Ratings, one of the nation's top three credit rating agencies, said, "Credit ratings are professional and objective."
When a credit rating agency with a good name issues a particular bond or a company's debt, until maturity
It is defined as a system that measures the ability to repay principal and interest and classifies it as a credit rating system
There is, and the role of credit rating is fair between bond issuers and investors in financial markets
By presenting professional opinions, investors can purchase, hold, and dispose of bonds
A person who provides information necessary for investment decision-making and who is subject to changes in market conditions to the issuer
By reducing the risk of raising gold while providing opportunities for stable capital raising, the financial market
It is suggested that it is to promote efficiency. 2) Based on the significance of this credit rating
A review of the current expanded credit rating area and development history from the beginning of the credit rating industry
Factors affecting credit ratings while testing the usefulness of high and credit rating information
Reviewing the usefulness and improvement factors of credit rating information by considering previous studies that have studied
It can be said to be a very meaningful study.
This study consists of the following five chapters. In "I. Raising Problems", the significance of credit rating is
The significance of the study and the meaning of the meaning were presented, and in "II. History of the Global Credit Rating Industry", Standard & Poor's Financial Services, the three international credit rating agencies
LLC), Moody's Investors Service, Inc, and Fitch IBCA's companies
The history of the development of the credit rating system was explained through the history.
In "III. History of Korea's Credit Rating Industry", Korea Credit Rating, Korea, the three domestic credit rating agencies
The results of Korea's credit rating system through the company history of Korea Credit Information and Korea Enterprise Evaluation
It explained the present and the future. In "IV. A Study on Credit Rating"
The usefulness of credit rating information and the factors affecting credit rating were reviewed. Lastly
In "V. Conclusion", the conclusion of the study was presented.

 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 4 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
summaries
# Out:
# tensor([[    0,   571,   410,     8,   998,  5773,   681,    11,  2580,  2603,
#            998,  9712,    58,  6306,   134,  8569,   908,   634,  1075,    13,
#            998,  5773,    19,    12,   915,  2725,    11,   771,  8479,   344,
#           6235,   962,    52,     7,    11,  4367,   188,     7,     3,     9,
#            741,    13, 15678,  1767,  2116,    30,  1566,    11,  7625,   807,
#              6,   796,  2580,  2603,   998,  9712,  3774,    54,   217,    24,
#             34,    31,     7,  6139,     5,     1],
#         [    0,  1615,   410,     8,   998,  5773,   358,  1344,    58,  6306,
#            134,  8569,   908,   188,     7,     3,     9,   741,    13, 15678,
#           1767,  2116,     6,    34,  4206,     7,    24,   126,   251,    45,
#              8,  2016,   998,  5773,  3193,    19,  1285,    11,    19,     3,
#          12999,    16,  1729,  3055,     5,     1,     0,     0,     0,     0,
# ...

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
decoded_summaries
# Out:
# [" How did the credit rating industry and factors affect credit ratings?[SEP]The role of credit rating is to present fair and professional opinions between bond issuers and investorsAs a result of reviewing previous studies on English and accounting issues, various factors affect credit ratingsYou can see that it's crazy.",
#  ' Why did the credit rating system develop?[SEP]As a result of reviewing previous studies, it recognizes that new information from the appropriate credit rating agency is included and is reflected in investment decisions.',
#  ' What are the strengths and shortcomings of the credit rating information used in the paper?[SEP]Content to accurately reflect the risk taken by bond issuers from a prospective investor.',
#  ' Where did credit rating become mandatory?[SEP]In the 1980s, the International Credit Rating Agency was integrated into the domestic credit rating industry as a foreign player.']

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "abstract.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)

# %% [markdown]
# # 1. 문제제기 부분 -> 7/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[content]
In the early days of the Korean bond market, collateral-oriented bonds dominated, and companies secured
Capital costs, such as securing and evaluating collateral, have increased. However, firms are lower
The wants to be financed by capital costs and participants in capital markets are at low risk
I wanted a good investment destination. Lower the capital cost of bond issuers and reduce the risk of investors
In order to do this, we need to solve the problem of information imbalance between companies and investors
Solve it. One of the systems for this is the credit rating system. 1) Therefore, the credit rating system's
The correct settlement is the information between the bond issuing company and the investor structurally inherent in the capital market
While reducing investors' risk by mitigating the imbalance, wealth by collateral or guarantee
Capital of the enterprise by avoiding rising movable property prices or security valuation costs
cost) can be reduced (Jindong-min, 2013).
Korea Ratings, one of the nation's top three credit rating agencies, said, "Credit ratings are professional and objective."
When a credit rating agency with a good name issues a particular bond or a company's debt, until maturity
It is defined as a system that measures the ability to repay principal and interest and classifies it as a credit rating system
There is, and the role of credit rating is fair between bond issuers and investors in financial markets
By presenting professional opinions, investors can purchase, hold, and dispose of bonds
A person who provides information necessary for investment decision-making and who is subject to changes in market conditions to the issuer
By reducing the risk of raising gold while providing opportunities for stable capital raising, the financial market
It is suggested that it is to promote efficiency. 2) Based on the significance of this credit rating
A review of the current expanded credit rating area and development history from the beginning of the credit rating industry
Factors affecting credit ratings while testing the usefulness of high and credit rating information
Reviewing the usefulness and improvement factors of credit rating information by considering previous studies that have studied
It can be said to be a very meaningful study.
This study consists of the following five chapters. In "I. Raising Problems", the significance of credit rating is
The significance of the study and the meaning of the meaning were presented, and in "II. History of the Global Credit Rating Industry", Standard & Poor's Financial Services, the three international credit rating agencies
LLC), Moody's Investors Service, Inc, and Fitch IBCA's companies
The history of the development of the credit rating system was explained through the history.
 In "III. History of Korea's Credit Rating Industry", Korea Credit Rating, Korea, the three domestic credit rating agencies
The results of Korea's credit rating system through the company history of Korea Credit Information and Korea Enterprise Evaluation
It explained the present and the future. In "IV. A Study on Credit Rating"
The usefulness of credit rating information and the factors affecting credit rating were reviewed. Lastly
In "V. Conclusion", the conclusion of the study was presented.


 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 7 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "part1.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)

# %% [markdown]
# # 2. 세계 신용평가산업의 역사 부분 -> 10/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[content]
Currently, the credit rating market is Standard & Poor's, the three international credit rating companies
Financial Services LLC), 무디스(Moody’s Investors Service,Inc) 그리고 피치 IBCA
Most of the credit rating market was dominated by (Fitch IBCA). Kim Byung-ki (2013) said, "Credit Ratings."
It is said that institutions are in the history of capital markets. 3)
The first capital markets were established in 1602 for Indian control and maritime trade
The Amsterdam Stock Exchange of the Netherlands, which was established with the aim of trading shares and bonds of
It is known. In the case of the United States, where capital markets are highly developed, major securities in New York in 1792
The New York Stock Exchange Board was launched in 1817 with rockers starting with the Burtonwood Agreement.
The bond market and credit rating industry in the United States began with the development of the railroad industry in 1850
Since then, railroad companies, which have grown rapidly, have made a lot of bonds for the purpose of raising funds to expand their businesses
It occurred, and as a result, the bond market, which was mainly government bonds, was converted to corporate bonds
The market began to expand. In the early days of the bond market, the credit rating of railroad companies was issued bonds
It was carried out by an investment bank that was in charge of over-acquisition, but in mid-1930 the Securities and Exchange Commission
Institutionalizing compulsory disclosure of information to securities issuers makes it easier for investors to access information
As a result, credit rating agencies such as Moody's began to evaluate the creditworthiness of U.S. railroad companies.
The American railroad company, which needed to raise money, had to raise insufficient funds from Europe
However, at that time, when the financial information or credit information of the bond issuing company was insufficient, the bond issuer and
It was difficult to raise funds due to the severe information imbalance with investors
C. Under these circumstances, Henry Poor wrote a specialized publication on the railroad industry in 1832
He published "The American Railroad," and in 1849 he published the financial information of railroad companies
It provides information about the Standard & Poor's. It was the beginning of Henry Poor's 1860
Henry Varnum Poor, son of the American Railroad Corporation, is an investor's guide
I'll issue it.
 In 1900, John Moody founded John Moody & Company communications, industry and diversity
Publication of Moody's Manual of Industrial and Miscellaneous Securities
Through this manual, various financial information of companies required by investors and
Statistics are provided.5) Capital market collapse in 1907 resulted in no capital to manage the enterprise
The former John Moody sells the manual business. However, in 1909, John Moody sold the United States Railroad Corporation's
Re-emerging with success by publishing a booklet analyzing the investment potential of stocks and bonds
So, in 1913, Moody's provided the credit rating of the bond market in its current preference system
On the other hand, it started not only corporate valuation but also public sector valuation projects
It takes the form of Moody's.
Meanwhile, Standard & Poor's was the predecessor of Standard & Poor's in 1916
Railroad is responsible for evaluating corporate bond credit ratings and national credit ratings
We'll start by merging Standard Statistics with Poor's Publishing in 1941
& Poor's has been established and provides financial information services in earnest.6)
Fitch IBCA was founded by John Knowles in 1913 by the founding of the Fitch Publishing Company
In 1924, when corporate bond evaluation began, credit evaluation information was provided in earnest. (Kim Byung)
Ki, 2013).
The history of the credit rating system is that as the capital market becomes more advanced, firms grow at a low cost of capital
Solving the imbalance of information in a situation where investors want to raise money and secure investment destinations
It's not an exaggeration to say that it started with the formation of a capital market
Starts in Amsterdam, Netherlands to trade shares and bonds in India Inc
However, the development of the credit rating industry was driven by the development of the American railway industry
It can be said that it is a company's financing (creating corporate bonds). The initial appearance of the credit rating industry began as a publishing industry that provides corporate financial information and various statistical data, but capital market participants
In the 1910s, credit rating services were carried out in earnest while demanding various information from this company
High credit rating information was provided.

 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 10 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
decoded_summaries
# Out:
# [' What type of information were provided by a credit rating agency',
#  " Where were credit rating agencies based?[SEP]IBCA and Moody's and the ERDF",
#  " Which company is mentioned at the end of the paper?[SEP]Fitch IBCA and Standard & Poor's",
#  ' According to the article, in which country are bonds issued most?[SEP]France, the UK, Spain and Canada.',
#  ' What is the financial information of the American railroad companies?[SEP]Financial information of the American railroad companies.',
#  " What year was Standard & Poor's founded?[SEP]1913",
#  " What are the names of the credit rating agencies that was founded in 1916?[SEP]John Knowles, Fitch IBCA, and Moody's Investors Service",
#  ' What are three characteristics of a credit rating agency?[SEP]They evaluate a variety of information including creditworthiness, economic performance, liquidity and customer rating.',
#  ' What is the second best known credit rating agency?[SEP]Moody’s',
# ...

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "part2.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)

# %% [markdown]
# # 3. 우리나라 신용평가산업의 역사 부분 -> 10/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[content]
The top three international credit rating agencies are Standard & Poor's, Moody's and Fitch IBCA
Korea's top three credit rating agencies are the Korea Investor Service (KIS),
National Credit Information (NICE) and the Korean flag
There is Korea Ratings (KR.7) Through the history of Korea's three major credit rating agencies
I would like to examine the history of the country's credit rating industry.8)
Korea Credit Rating was established as "Corporate Financial Information Center" in February 1985 and "Korea Credit" in May 1985
The company name was changed to Evaluation (Co., Ltd.) In September 1985, the company began evaluating corporate drafts (CPs)
In September 1985, corporate bond evaluation began. In 1997 and 1998, securities bonds, stock funds, and,
It started credit rating services for leases, cards, installment financing and new technology financial bonds. 1998
It became independent as a joint venture with Moody's in August, 1998, and the best among domestic credit rating agencies in November 1998
By introducing the Watchlist system and the Rating Outlook and Issuer Rating, investors have been encouraged to do so
It is responding to the demand for expanding credit rating information. In January 1999, banks, guarantee agencies, public enterprises, and assets
It started the credit rating business of floating securities and evaluated the first Issuer rating in Korea in March 2003
The work and evaluation of the first school corporation in Korea began in May 2005.
 In December 2001, it was incorporated into Moody's, a global credit rating agency, and in July 2016
As Moody's 100% stake has been incorporated into a subsidiary, it provides international-level credit rating services
I'm trying to make it public. Recognize new business environment changes more quickly and grade them in a timely manner
Introducing Moody's advanced evaluation system and carrying out fair evaluation work to reflect it in the calculation
Thus, it aims to contribute to the advancement of the capital market. In addition, fund evaluation and support
Development of new evaluation markets and new evaluation markets such as Munical Bond evaluation and Loan Rating
It is promoting the advancement of the capital market using credit rating through the development of evaluation techniques.
Korea Enterprise Evaluation Co., Ltd. started with Korea Management Consulting Co., Ltd. in December 1983 and began business feasibility review and corporate diagnosis in January 1984. In November 1987, the name of the company was Korea Enterprise Evaluation Co., Ltd
It was changed and designated as a corporate bond credit rating agency. Credit for corporate bills in December 1988
The evaluation service was started, designated as a credit rating agency in July 1994, and January 1999
A credit rating agreement was signed with Fitch IBCA. In January 2001, Fitch Ratings, Ltd
FITCH participated in capital and acquired shares of FITCH in April 2007 by FITCH Ratings, Ltd
RATINGS is currently the majority shareholder with a 73.55% stake. Currently, credit rating as a major business
It is divided into business valuation and credit valuation for securities such as corporate bonds, ABS, corporate bills, etc
Credit rating is being carried out, and business valuation is based on financial and financial sectors
It is carrying out a combined service.
 NICE Credit Rating Co., Ltd. was established as a comprehensive national credit rating in September 1986.11 in 1987
It was selected as a specialized rating agency for corporate bonds, and related to credit transactions of financial institutions in January 1989
Professional enterprise analysis was conducted. In January 1991, at the National Comprehensive Credit Rating, Korea Credit
The company name was changed to Information Co., Ltd., and in July 1995, a credit information business license was obtained. In 1998
China's New World in May 2007 after partnering with Duff & Phelps Credit Rating Co. of the U.S
Business partnership with Yongpyongsa Dagong, Hanshinjeong Evaluation Co., Ltd. and company separation in September 2007, September 2011
The name was changed from Hanshin Evaluation Co., Ltd. to NICE Credit Evaluation Co., Ltd. NICE Credit Evaluation is a company
Credit rating evaluation of bills, corporate bonds, financial bonds, insurance payment capacity and asset-backed securities (ABS), etc
It is carrying out political affairs and deals with domestic and foreign real estate development projects and SOC private investment projects
A business performance evaluation and credit rating evaluation on the ability to repay the principal and interest of PF loans in a timely manner
It is carrying out business performance evaluation, stock valuation, intangible asset valuation, brand valuation
A and court investigator services are being carried out.
In Korea's early bond market, collateral-oriented bonds dominate credit ratings
The need was not great. The issuance of bonds by collateral is collateral procurement and collateral appraisal
It has incurred many capital costs, etc. However, due to industrial development, companies have various funds
There has been a widespread desire to find sources of procurement and raise funds at low capital costs, capital
Participants in the market use more corporate information to reduce investment risk
There was a great desire.
As a result, if the issuance of unsecured corporate bonds by corporate credit is expanded and multiple evaluations are mandatory
As the demand for credit rating information grows, it has the appearance of three domestic credit rating companies in the 1980s
Dancing.9) Furthermore, to introduce international credit rating techniques, three major international alternatives
Beyond business agreements with utility rating agencies, it is incorporated into international credit rating agencies or expands its stake. It also evaluates electronic short-term bond credit ratings, independent credit ratings considering the possibility of subsidiary support,
Advancement of the capital market by expanding business areas such as brand valuation and intangible asset valuation
be on the cards.

 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 10 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "part3.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)

# %% [markdown]
# # 4. 신용평가 관련 연구에 관한 고찰 부분 -> 15/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[content]
1. A Study on the Usefulness of Credit Rating Information
The credit rating industry developed for the purpose of smooth financing due to the development of the railroad industry in the United States
It became. After that, it expanded its scope to credit ratings not only for corporate bonds but also for government and public bonds
Meanwhile, credit ratings for intangible assets are now introduced to promote the advancement of the capital market
Therefore, credit rating information based on credit ratings is useful for capital market participants
It can be seen through the historical consideration of the credit rating industry that it is recognized as information
Therefore, in this study, whether credit rating information is recognized as useful information in the capital market
I would like to review previous studies that have been empirically analyzed.
Pinch and Singleton (1978) are representative studies that tested the usefulness of credit rating information,
Holthausen and Leftwich (1986), Goh and Edrington (1993), Jindongmin (2002) and You Young
A study by Lee and Kim Sun-gu (2010) can be cited.
 In a study by Pinch and Singleton (1978) on the financial status of a company, bond rating information
Therefore, it is recognized that it is useful information provided by a specialized institution called a credit rating agency and is rated as a bond
The effect of information disclosure on a company's stock price return was tested. The study period began in 1950
By 1972, 207 companies were classified into credit rating companies and rating companies
Here, the effect of a change in credit rating on the stock price was empirically analyzed. As a result of the study, Shin
The cumulative average excess return of companies whose dragon rating has risen will be changed from 26 months after the announcement of the rating
In the case of companies that have continued to rise until the date and whose credit rating has declined, 25 months before the disclosure
The test results were presented. Credit rating change information through these test results
is recognized as useful information for participants in the capital market and influences investment decisions
The results of the study were presented.
Holthausen and Leftwich (1986) to analyze the information effects of bond rating changes
Daily stock price to minimize the noise of other information after defining a definite disclosure date
It was tested using data. In addition, in order to test the significance of changes in bond ratings
Through multiple regression analysis, the causal relationship between variables was identified, and furthermore, class changes were predicted
The information effect according to the disclosure of the credit watch list was tested. 10) As a result of the verification, in the case of downgrade, it was statistically significant in the within-class rating changes
One excess return has not been tested, but in cross-class rating changes
A statistically significant negative (-) excess return was tested. On the other hand, in the case of a grade increase
Statistically significant excess returns were not tested in all urgent cases,
The results of a study suggesting that credit rating information is recognized as useful information in the capital market
It was.
 Goh and Edrington (1993) found that a decline in credit ratings would lead to future benefits
However, if it is due to the prediction of a decrease in sales, it will have a negative impact on the capital market
Otherwise, if the decline in bond ratings is bizarre for predictions of increased leverage
It was predicted that it would have a positive (+) effect on the capital market. In other words, the overall value of the company changes
Assuming that it is not, if the value of the bond falls (increases) in the bond market, the stock in the stock market
The value is that there is a negative (-) relationship that rises (declines). Therefore, the credit rating decline remains unchanged
Wealth is transferred from the authorized person to the shareholders, statistically significant to the return on common stock
The transfer of wealth that has a positive (+) effect was empirically analyzed. The research method is the market
The daily excess return was calculated using the model, which is statistically significant in the case of a decline
It wasn't.
According to a study by Jin Dong-min (2002), a short-term financing method in the domestic bond market since 1972
Although short-term corporate bills were introduced for the first time, they are structurally embedded in the capital market
Sufficient activities due to information imbalance between bond issuing companies and investors
The problem was raised that it was not being activated. Accordingly, the usefulness of credit rating information is tested
The study period was from 1998 to 2000, and the credit rating of the three domestic credit rating agencies
It was targeted at publicly disclosed companies. Credit rating to test the information effect of credit rating
The disclosure is defined as an event, and the credit rating disclosure date is defined as the event day
Event study to test the correlation between credit rating disclosure information and stock prices
It was tested as . The expected rate of return was calculated using the market model method, and the credit rating disclosure date
Estimation period (estimation) from 160 days (-160) before disclosure to 60 days (-60 days) before disclosure based on (0 days)
It is defined as period), and 10 days (±10) before and after disclosure is defined as the test period and exceeds it
The rate of return was statistically tested.11) As a result of the study, the information effect of disclosure of credit rating change information affects the capital market in all cases where the credit rating falls or rises
It was found that these research results show the expertise of credit rating agencies in credit rating information
New information that has not been previously disclosed is provided to participants in the capital market
Research results that are recognized as useful information are presented.
In a study by Yoo Young-yi and Kim Sun-gu (2010), the difference in asset revaluation was due to the effect of improving the financial structure
Therefore, it has a positive effect on a company's credit rating, which significantly affects the stock price of the capital market
Relation to affect the response of the stock market by the change in credit rating
Variables were tested. Also, differences in variables between firms that adjust credit ratings up and down, up and down, up and down
Whether there is a difference in related variables by subdividing them into intra- and inter-grade adjustment companies of regular companies
It was verified. The study period was from January 1, 2009 to June 30, 2009 among companies that conducted asset revaluation
Companies that received credit ratings were selected. If it is a manufacturing industry among companies that received credit ratings
The sample is defined as a settlement corporation in December, and the credit rating has changed between grades or within grades
Companies were selected as samples.
However, companies that are subject to management or have a credit rating that has fallen to D
Excluded from the sample. Finally, financial and stock price data are available in kis-value
As a result of the credit rating, there will be an event that affects the stock price within 4 weeks (-4 weeks) before the date of disclosure
It was defined as a company that was not. The final sample selected based on the sample selection criteria was 138 companies
It was tested on . The research model was accumulated for ±10 days before and after the date of disclosure of the credit rating change
Excess return was used as the dependent variable. Variables related to changes in credit ratings and asset revaluation
It is used as a major independent variable and is expected to affect the stock price return 4
A cross-sectional analysis is conducted using individual independent variables. As a result of the study, ash by asset revaluation
The difference in valuation has the effect of improving the financial structure, raising the credit rating, and improving the soundness of the financial structure
We presented the test result in which the stock price responded positively with anticipation. However, between credit ratings
In the case of upward/downward adjustment companies, statistically significant variables have not been tested, so re-evaluation is implemented
Investors reflect information in advance on Bo, resulting in a stock price response at the time of disclosure
It was argued that it was not. What can be seen from the research results is that capital market participants are self-sufficient
It provides useful information on industrial accident evaluation and reflects it in investment decisions
The results of the study were presented that it was tested by changes in credit rating.
The credit rating industry has developed to provide useful information for investors' decision-making
Therefore, participants in the capital market have credit ratings announced by credit rating agencies
New information from professional credit rating agencies based on financial and non-financial information
Previous studies have shown that recognizing that is included and reflecting it in investment decision-making
It can be seen through the time difference. However, in future studies, the definition of the disclosure date, time difference
lag) and testing for information leakage is required, and above all, even though only the effectiveness of credit rating information should be tested, the contamination of information
It contains problems such as control. 2. Consideration of research on factors affecting credit rating
The credit rating industry has developed with the aim of providing more useful information to the capital market,
The credit rating information effect was tested as useful information through previous studies. Also, credit rating
A number of studies have also been conducted on the factors affecting A. Various management and accounting factors
To test the impact of issue on credit rating and to increase credit rating
A study was conducted to reduce the cost of capital by doing so. The impact of corporate governance
Kim Moon-tae and Kim Young-hwan (2007), Yang Dong-jae et al. (2011), who studied the impact of debt guarantees, internal accounting
Non-level (2012), Jin Dong-min (2013), who studied the relevance of corporate value, and others who studied the personnel in charge
A representative study by Park Jin-ha et al. (2015), who studied the relationship with labor unions.
A study by Kim Moon-tae and Kim Young-hwan (2007) is based on the credit rating and corporate governance of foreign investors
The relevance of ubiquity and outside directors was empirically analyzed. Credit as a proxy for credit rating
Based on the credit rating data disclosed by the Korea Credit Rating Agency, 20 points were given to AAA,
AA+ 19 points… It was defined as a dependent variable of the research model as a step-by-step equal interval score of 2 points C and 1 point D
C. The ownership ratio of foreign investors to test "Hypothesis 1" as an independent variable of the research model and "Hypothesis 2"
A 'time difference' research model was designed by defining the characteristics of outside directors (Hypothesis 2)
The old period was from 2000 to 2006, targeting listed companies that issued corporate bonds. Enterprises
Variables related to governance are checked in the Financial Supervisory Service's electronic disclosure system (www.dart.or.kr )
A sample that can be obtained from KIS-VALUE of Korea Credit Rating Information Co., Ltd
It was selected as . Manufacturing industry that continued to be listed during the study period, December settlement corporation was selected as a sample
As a result, the final sample was selected as 841 (yearly/credit rating). As a result of the study, the foreign equity ratio,
Ratio of outside directors of the board of directors, ratio of all outside directors appointed to the audit committee, and ratio of outside directors
It was tested that the social attendance rate, etc., had a very high correlation with credit rating. In addition
As a result of linear regression and logit analysis, foreign ownership, ratio of outside directors of the board of directors, audit committee members
The main independent variables, such as the proportion of all outside directors elected to the board of directors and the ratio of outside directors to attend the board of directors, were tested for a statistically significant positive (+) relationship with credit rating. This is a result of foreign investors'
The monitoring function, independence of the board of directors and the audit committee, and the activities of outside directors are positive for the credit rating evaluation
It was suggested as a result of the study that it had a positive effect.
In a study by Yang Dong-jae et al. (2011), the effect of debt guarantee on the credit rating of guaranteed companies
It was tested and tested whether or not to belong to a large corporate group responded differently. Warranty
Debt guarantees between the company and the guaranteed company are made in order for the guaranteed company to borrow funds from a third party
When the guaranteed entity guarantees the repayment of principal and interest of the debt, the guaranteed entity repays the debt
When they can't, they have to bear the liabilities of the guaranteeing company, so creditors also have to pay for debt guarantees
It shows a sensitive reaction to it, and creditors in particular have an important factor in a company's ability to repay its debt
Recognizing that, it raised a question that this would affect credit rating evaluation. Meanwhile,
Korea is required to completely eliminate existing debt guarantees by March 2000
Subsequently, they belong to large corporate groups and large corporate groups belonging to large corporate groups
It was tested whether it appeared differently according to wealth. The research period for empirical analysis was 2002
Large-scale business groups under the ｢Monopoly Regulation and Fair Trade Act｣ from 2006 to 2006 (five years)
It was targeted after the debt guarantee of was prohibited. Settlement of accounts in December from 2002 to 2006
It was limited to the manufacturing industry among corporations. The sample finally selected based on the sample selection criteria was
There are 359. As a result of the study, the lower the debt guarantee, the higher the credit rating
It was found that the more companies belonging to a large corporate group, the more pronounced this situation was
C. However, no significant difference was tested in belonging to large corporate groups.
Accordingly, credit rating
A study suggests that institutions consider whether they belong to large business groups in credit ratings
It was.
Chae Sang-dae et al. (2012) include the United States and other taxes after large-scale accounting frauds such as Enron and WorldCom
The demand for increased capital market reliability has increased in the system and, therefore, the internal control system has become
Better companies have greater transparency in financial information than those that don't, and credit rating agencies have greater transparency in their financial information
They argued that they would evaluate positively when evaluating Korean credit. Accordingly, the internal accounting management system
An empirical analysis was conducted on how effective human resource investment affects credit ratings
C. The study period is from 2002 to 2008, and as of December 31, 2009, the Korea Stock Exchange
Among the listed companies, the financial industry was excluded as a December settlement corporation. And internal meetings
The accounting management system is defined as an enterprise that can collect data on the current status of manpower, credit rating, and share ratio
The number of samples finally selected according to the sample selection criteria is 1,554 (company/year).
The research method is a proxy variable for credit rating, and the best is the corporate bond credit rating of the three credit rating companies
Level AAA is given a step-by-step score of 1 point from 20 points to C and used as a dependent variable (t+1)
The parallax model was established by defining the size of internal accounting management personnel, the average number of months of experience of internal accounting management personnel, and whether or not a certified public accountant was assigned (t phase) as independent variables. As a result of the study,
The size of internal accounting personnel, the average number of months of experience, and the number of certified public accountants
It was tested that the credit rating was high. This is because internal accounting experts invest accounting information
Research results suggesting that they receive high credit ratings by enhancing their reputation.
According to a study by Jin Dong-min (2013), the International Monetary Fund (IMF) foreign exchange committee at the end of 1997
Subprime mortgage crisis in 2007 and September 2008
The international financial crisis caused by Lehman Brothers bankruptcy is a national credit
Claims that Donna's corporate credit rating became an opportunity to be recognized as very important in society
Accordingly, it is a substitute for corporate value for corporate bills issued by short-term creditworthiness
(proxy) is defined as Tobin's Q to empirically demonstrate the impact of credit ratings on corporate value
It was analyzed. The study period was to control the impact of the international financial crisis in 2008
It was set for three years from 2010 to 2012. The sample is KOSPI-listed companies and finance
Excluding business and construction businesses, the corporation was selected as a settlement corporation in December, and the audit opinion was "appropriate opinion."
It was limited to companies. Finally, 234 samples were selected based on the sample selection criteria
The dependent variable of the research model is defined as Tobin's Q as a proxy for corporate value
In addition, the major independent variable of the study, the rating of the corporate paper is 12 levels
After Noor quantification, it is used as a variable in the model and other dependent variable Tobun's Q
was used in the research model as an influencing variable as a control variable. As a result of the study, credit
The statistical significance of grade and corporate value was tested. This is the capital market where credit rating information is used
It tested that it was recognized as useful information and, in particular, assessed the short-term creditworthiness of an entity
The assessment of corporate paper credit is focused on liquidity and cash flow
presented as a result of the study. 13)
In a study by Park Jin-ha et al. (2015), credit rating agencies include financial statements and other financial statements
Non-financial information such as industry analysis, sales analysis, and business management analysis, as well as enemy information
Since the credit rating is determined after analyzing including the report, the labor union determines the credit rating of the company's bond
the measurement of non-financial information to determine the scope of financial information from previous studies by analyzing its impact on
An empirical analysis was conducted by expanding the scope of the study. The study period was from 1998 to 2008 among listed companies
Companies excluding the financial industry were selected as samples. The number of final samples was 919 from 236 companies
A company/year sample was selected. It was verified whether the existence of a labor union acts as a negative factor in the credit rating and lowers the bond credit rating. Meanwhile, studies related to labor unions have
Negotiation of trade unions with or without unions in analyzing the impact of trade unions on enterprises
It is looking at how strong the force is. The second hypothesis of Park Jin-ha et al. (2015) is labor
If the union's bargaining power is strong, it acts as a negative factor in the credit rating, resulting in a low bond credit rating
We verified the knowledge. As a result of the study, trade unions exist and trade unions have strong bargaining power
The more you do, the lower your credit rating is. In addition, the differences between the three credit rating agencies are tested
As a result, all three credit rating agencies were tested to consider the bargaining power of trade unions
However, the results of the study were presented that the differences between the three credit rating agencies were not tested.
Diverse results of research on management and accounting issues affecting credit ratings
One factor was tested to affect credit rating. Corporate governance may be sound
That is, the ratio of foreigners' shares, the ratio of outside directors of the board of directors, and all outside directors appointed to the Audit Committee
The higher the proportion of outside directors to attend the board of directors, the more they do not belong to the large corporate group
If there is no guarantee, the more professional the internal accounting staff is and there is no labor union
The lower the bargaining power, the more positive the credit rating was tested. Also, this
It can be seen from the consideration of previous studies that such credit ratings affect corporate value
It was here.
A common limitation of research on factors affecting credit ratings is that credit rating agencies are
The credit rating is determined by reflecting financial and non-financial information and the variables or weights considered
It is impossible to define objectively. Therefore, the statement of omitted variables
I present it as a future research project.


 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 15 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "part4.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)

# %% [markdown]
# # 5. 결론 부분 -> 4/50개만 만듦

# %%
txt=r"""
Generate Question, Answer pair correspond to the following paper.
[content]
The credit rating system lowers the cost of capital for bond issuers and reduces the risk of investors
By addressing the problem of information imbalance between risk companies and investors
It has the effect of promoting the efficiency of the capital market.14) Therefore, in this study, the significance of credit rating is
Based on the intentions, the current expanded credit rating area and publication of the credit rating industry from the beginning of the credit rating industry
Reviewing the entire history, testing the usefulness of credit rating information, and reflecting the credit rating
It is meaningful to examine the usefulness and improvement factors of credit rating information by reviewing previous studies that have studied the factors affecting it.
As a result of the study, the first reason for the development of the credit rating industry was the development of the railroad industry in the United States
It can be said that it is due to the financing of a railroad company (issuance of corporate bonds). The beginning of the credit rating industry
Its appearance began with the publishing industry, which provides financial information and various statistical data of companies
B, Credit rating business in earnest in the 1910s at the request of investors for various corporate information
The performance was performed and credit rating information was provided. This means that as the capital market became more advanced, companies were able to
When you want to raise money at a low cost of capital, and investors want a safe place to invest
It can be said that the purpose is to resolve the imbalance of information. Second, the early days of Korea
The bond market also did not have much need for credit ratings. However, companies have a variety of funds
There has been a widespread desire to find sources of procurement and raise funds at low capital costs, capital
market participants' desire to use more corporate information to reduce investment risk
The district was large. Therefore, the issuance of unsecured bonds by credit is expanded and multiple valuation is mandatory
As the demand for the credit rating industry grew, three domestic credit rating companies in the 1980s
It has come to appearance. Furthermore, to introduce international credit rating techniques, international
Whether it is incorporated into an international credit rating agency beyond business agreements with the three major credit rating agencies
The fraction is expanding. Also, considering the possibility of electronic short-term bond credit rating, affiliated support
Capital city by expanding business areas such as credit rating, brand valuation, intangible asset valuation, etc
It is trying to advance the field.
Third, the credit rating industry is launched to provide useful information for investors' decision-making
Accordingly, participants in the capital market have received credit rating information published by credit rating agencies
New information from professional credit rating agencies is included based on financial and non-financial information
Through the consideration of previous studies, it is recognized that it is and reflected in investment decision-making
You can see. Fourth, management and accounting issues that affect credit ratings
As a result of examining the research, various factors were tested to influence credit ratings
C. However, credit rating agencies determine credit ratings by reflecting financial and non-financial information
However, it is impossible to objectively define the variables or weights considered
Therefore, various studies on the problem of omitted variables are needed.

 Question, Answer:
 """.replace("\n", "")

# %%
inputs = tokenizer(txt, max_length = 1024, truncation=True, padding="max_length", return_tensors="pt")

# %%
#for multiple question generator
num_generate_sequence = 4 #8, 16, 2, 1
summaries = model.generate(input_ids =inputs["input_ids"], max_new_tokens=100, do_sample = True, top_p = 0.95, num_return_sequences = num_generate_sequence)

# %%
decoded_summaries = [tokenizer.decode(s, skip_special_tokens=False, clean_up_tokenization_spaces=True) for s in summaries]
decoded_summaries = [d.replace("<n>", " ").replace(tokenizer.pad_token, "").replace(tokenizer.eos_token, "") for d in decoded_summaries]

# %%
from google.colab import files

# Join the list items into a single string
text_to_write = '\n'.join(decoded_summaries)

# Define the file path
file_path = "conclusion.txt"  # Change this to your desired file path

# Write the text to a file
with open(file_path, 'w') as file:
    file.write(text_to_write)

# Download the file
files.download(file_path)
